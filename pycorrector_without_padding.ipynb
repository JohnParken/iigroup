# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnParken/iigroup/blob/master/pycorrector_without_padding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 准备工作

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs')

# %%
# !pip install -r requirements.txt
# !pip install pyltp
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.39)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.21.3)
# Collecting pypinyin
#   Downloading https://files.pythonhosted.org/packages/24/b9/ade53a5211136b51b046c16466de9e31e2543e25691582fe088d37b7f64f/pypinyin-0.36.0-py2.py3-none-any.whl (779kB)
#      |████████████████████████████████| 788kB 9.6MB/s
# Collecting kenlm==0.0.0
#   Downloading https://files.pythonhosted.org/packages/57/54/0cc492b8d7aceb17a9164c6e6b9c9afc2c73706bb39324e8f6fa02f7134a/kenlm-0.tar.gz (1.4MB)
#      |████████████████████████████████| 1.5MB 55.9MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy->-r requirements.txt (line 2)) (1.17.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (0.14.1)
# Building wheels for collected packages: kenlm
#   Building wheel for kenlm (setup.py) ... done
#   Created wheel for kenlm: filename=kenlm-0.0.0-cp36-cp36m-linux_x86_64.whl size=2272527 sha256=0b760403e762b2ec5a9758049647feded15b328f2b492e490328453d767c1440
#   Stored in directory: /root/.cache/pip/wheels/e9/cf/f4/1a1aab56f87f4132667a7a47045a750384f19d646099ab4858
# Successfully built kenlm
# Installing collected packages: pypinyin, kenlm
# Successfully installed kenlm-0.0.0 pypinyin-0.36.0
# Collecting pyltp
#   Downloading https://files.pythonhosted.org/packages/aa/72/2d88c54618cf4d8916832950374a6f265e12289fa9870aeb340800a28a62/pyltp-0.2.1.tar.gz (5.3MB)
#      |████████████████████████████████| 5.3MB 7.2MB/s
# Building wheels for collected packages: pyltp
#   Building wheel for pyltp (setup.py) ... done
#   Created wheel for pyltp: filename=pyltp-0.2.1-cp36-cp36m-linux_x86_64.whl size=31967668 sha256=c6d9edb72b9b4a96386569602648c4e5ed58d249d2aad7402aa47ac35548445a
#   Stored in directory: /root/.cache/pip/wheels/fc/3a/35/b11293efb2c77c0e7b6fa574271d51cddd9abd1f634535343c
# Successfully built pyltp
# Installing collected packages: pyltp
# Successfully installed pyltp-0.2.1

# %%
import pycorrector
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ### 测试结果

# %%
sent, detail = pycorrector.correct('我是你的眼')
# Out:
# [  DEBUG 20191213 05:40:28 corrector:110] Loaded same pinyin file: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/same_pinyin.txt, same stroke file: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/same_stroke.txt, spend: 1.434 s.
# [  DEBUG 20191213 05:40:32 detector:66] Loaded language model: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/kenlm/people_chars_lm.klm, spend: 3.8723254203796387 s
# [  DEBUG 20191213 05:40:34 detector:73] Loaded word freq file: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/word_freq.txt, size: 583280, spend: 2.345494270324707 s
# [  DEBUG 20191213 05:40:34 detector:78] Loaded confusion file: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/custom_confusion.txt, size: 1767, spend: 0.3234586715698242 s
# [  DEBUG 20191213 05:40:36 detector:92] Loaded custom word file: /content/drive/My Drive/Colab Notebooks/PyTorch/data/pycorrector-words/pycorrector-master-new-abs/pycorrector/data/custom_confusion.txt, size: 59779, spend: 1.984581470489502 s
# [   INFO 20191213 05:40:38 detector:96] Loaded dict ok, spend: 10.301344156265259 s
# [('我', 0, 1), ('是', 1, 2), ('你的', 2, 4), ('眼', 4, 5)]
# ngram: n=2
# [-5.1474714279174805, -5.1474714279174805, -9.68696403503418, -11.08054256439209, -11.08054256439209]
# ngram: n=3
# [-13.048788070678711, -13.048788070678711, -13.048788070678711, -14.168066024780273, -14.168066024780273, -14.168066024780273]
# med_abs_deviation: 1.1023775339126587
# y_score: [1.31936855 0.51084569 0.51084569 0.83815431]
# median: [-11.25445628]
# scores: [ -9.09812975 -10.41954923 -12.08936334 -12.62430429]

# %%
print(sent,detail)
# Out:
# 我是你的眼 []

# %%
sentences = [
             '他们都很饿了，需要一些食物来充饥',
             '关于外交事务，我们必须十分谨慎才可以的',
             '他们都很饿了，需要一些事物来充饥',
             '关于外交事物，我们必须十分谨慎才可以的',
             '关于外交食务，我们必须十分谨慎才可以的',
             '这些方法是非常实用的',
             '这些方法是非常食用的',
             '高老师的植物是什么你知道吗',
             '高老师的值务是什么你知道吗',
             '高老师的职务是什么你知道马',
             '你的行为让我们赶到非常震惊',
             '你的行为让我们感到非常震惊',
             '他的医生都将在遗憾当中度过',
             '目前的形势对我们非常有力',
             '权力和义务是对等的，我们在行使权利的同时，也必须履行相关的义五',
             '权力和义务是对等的，我们在行使权力的同时',
             '权利和义务是对等的',
             '新讲生产建设兵团',
             '坐位新时代的接班人'
             '物理取闹',
             '我们不太敢说话了已经',
             '此函数其实就是将环境变量座位在path参数里面做替换，如果环境变量不存在，就原样返回。'

]

for sentence in sentences:
  sent, detail = pycorrector.correct(sentence)
  print(sent, detail)
  print('\n')
# Out:
# [WARNING 20191213 05:40:38 detector:409] detect error, sentence:权力和义务是对等的,我们在行使权利的同时,也必须履行相关的义五'tuple' object has no attribute 'strip'
# [('他们', 0, 2), ('都', 2, 3), ('很', 3, 4), ('饿', 4, 5), ('了', 5, 6), (',', 6, 7), ('需要', 7, 9), ('一些', 9, 11), ('食物', 11, 13), ('来', 13, 14), ('充饥', 14, 16)]
# ngram: n=2
# [-5.418898582458496, -5.418898582458496, -4.664351463317871, -6.906415939331055, -5.395123481750488, -5.325242042541504, -5.845865249633789, -6.048429489135742, -6.460465431213379, -6.186435699462891, -7.609062671661377, -7.609062671661377]
# ngram: n=3
# [-6.518762588500977, -6.518762588500977, -6.518762588500977, -8.749101638793945, -7.788795471191406, -7.5064496994018555, -8.573263168334961, -8.662345886230469, -9.289972305297852, -9.06784439086914, -11.140613555908203, -11.140613555908203, -11.140613555908203]
# med_abs_deviation: 0.5478081703186035
# y_score: [1.37156803 1.14613917 0.42762948 0.         0.52279728 0.20478823
#  0.38382137 0.6745     1.22555036 1.95888212 2.82214831]
# median: [-7.08277599]
# scores: [-5.96883059 -6.15191698 -6.73546847 -7.08277599 -6.6581761  -6.91645328
#  -7.39450391 -7.63058416 -8.07813032 -8.67371984 -9.37483811]
# 他们都很饿了，需要一些食物来充饥 []
#
#
# [('关于', 0, 2), ('外交事务', 2, 6), (',', 6, 7), ('我们', 7, 9), ('必须', 9, 11), ('十', 11, 12), ('分', 12, 13), ('谨慎', 13, 15), ('才', 15, 16), ('可以', 16, 18), ('的', 18, 19)]
# ngram: n=2
# [-10.726645469665527, -10.726645469665527, -9.44794750213623, -5.359715938568115, -6.163232326507568, -7.981159210205078, -8.126656532287598, -8.611581802368164, -8.21739387512207, -5.210103988647461, -5.497365951538086, -5.497365951538086]
# ngram: n=3
# [-13.575152397155762, -13.575152397155762, -13.575152397155762, -11.95915699005127, -7.43984317779541, -10.874946594238281, -12.187893867492676, -13.07942008972168, -12.34787368774414, -10.168984413146973, -7.879795551300049, -7.879795551300049, -7.879795551300049]
# med_abs_deviation: 1.2561495701471976
# y_score: [1.58579425 1.26952199 0.         0.68258849 0.31021666 0.45805558
#  0.6745     0.50600216 0.41594112 1.18093852 1.34724311]
# median: [-9.19760795]
# scores: [-12.15089893 -11.56189187  -9.19760795  -7.92639486  -8.61987849
#  -10.05066403 -10.45375752 -10.13995695  -8.42298341  -6.99829674
#   -6.68858075]
# 关于外交事务，我们必须十分谨慎才可以的 []
#
#
# [('他们', 0, 2), ('都', 2, 3), ('很', 3, 4), ('饿', 4, 5), ('了', 5, 6), (',', 6, 7), ('需要', 7, 9), ('一些', 9, 11), ('事物', 11, 13), ('来', 13, 14), ('充饥', 14, 16)]
# ngram: n=2
# [-5.418898582458496, -5.418898582458496, -4.664351463317871, -6.906415939331055, -5.395123481750488, -5.325242042541504, -5.845865249633789, -6.048429489135742, -7.34495210647583, -8.187288284301758, -7.609062671661377, -7.609062671661377]
# ngram: n=3
# [-6.518762588500977, -6.518762588500977, -6.518762588500977, -8.749101638793945, -7.788795471191406, -7.5064496994018555, -8.573263168334961, -8.662345886230469, -10.174459457397461, -10.841046333312988, -12.81308364868164, -12.81308364868164, -12.81308364868164]
# med_abs_deviation: 0.9308590094248457
# y_score: [0.80716432 0.6745     0.25165887 0.         0.30766488 0.12051736
#  0.3326944  0.87812624 1.7668507  2.13335194 2.26676266]
# median: [-7.08277599]
# scores: [ -5.96883059  -6.15191698  -6.73546847  -7.08277599  -6.6581761
#   -6.91645328  -7.54191844  -8.29465401  -9.52115834 -10.02695668
#  -10.21107316]
# 他们都很饿了，需要一些事物来充饥 []
#
#
# [('关于', 0, 2), ('外交', 2, 4), ('事物', 4, 6), (',', 6, 7), ('我们', 7, 9), ('必须', 9, 11), ('十', 11, 12), ('分', 12, 13), ('谨慎', 13, 15), ('才', 15, 16), ('可以', 16, 18), ('的', 18, 19)]
# ngram: n=2
#
#
# cut_words:
# [('权力', 0, 2), ('和义', 2, 4), ('务是', 4, 6), ('对', 6, 7), ('等', 7, 8), ('的', 8, 9), (',', 9, 10), ('我们', 10, 12), ('在', 12, 13), ('行使权力', 13, 17), ('的', 17, 18), ('同时', 18, 20)]
# ngram: n=2
# [-11.165401458740234, -11.165401458740234, -13.198881149291992, -9.4202241897583, -5.796807289123535, -4.55974817276001, -5.199775695800781, -5.359715938568115, -5.341310977935791, -9.665081024169922, -8.474891662597656, -4.509489059448242, -4.509489059448242]
# ngram: n=3
# [-17.764842987060547, -17.764842987060547, -17.764842987060547, -16.019664764404297, -12.396247863769531, -7.925103664398193, -8.214109420776367, -7.983367919921875, -7.195198059082031, -12.94481086730957, -11.540532112121582, -11.108928680419922, -11.108928680419922, -11.108928680419922]
# med_abs_deviation: 1.598323186238607
# y_score: [2.32652553 2.41831447 1.85660074 0.38360365 0.67817929 1.05154289
#  1.01848261 0.67082071 0.03359047 0.63945579 0.03359047 0.48230162]
# median: [-8.9520908]
# scores: [-14.46512222 -14.68262911 -13.35156894  -9.86109392  -7.34504902
#   -6.46031113  -6.53865214  -7.3624862   -9.03168817 -10.46737178
#   -8.87249343  -7.80920887]
# 权力和义武是对等的，我们在行使权力的同时 [['务是', '武是', 4, 6]]
#
#
# cut_words:
# [('权利', 0, 2), ('和义', 2, 4), ('务是', 4, 6), ('对', 6, 7), ('等', 7, 8), ('的', 8, 9)]
# ngram: n=2
# [-11.403175354003906, -11.403175354003906, -13.198881149291992, -9.4202241897583, -5.796807289123535, -4.55974817276001, -4.55974817276001]
# ngram: n=3
# [-18.00261688232422, -18.00261688232422, -18.00261688232422, -16.019664764404297, -12.396247863769531, -7.925103664398193, -7.925103664398193, -7.925103664398193]
# med_abs_deviation: 3.1359674135843907
# y_score: [0.66176326 0.68723674 0.37963646 0.37963646 0.93116048 1.15795819]
# median: [-11.62614592]
# scores: [-14.70289612 -14.82133055 -13.39119792  -9.86109392  -7.2968814
#   -6.24242592]
# 权利和义武是对等的 [['务是', '武是', 4, 6]]
#
#
# [('新', 0, 1), ('讲', 1, 2), ('生产', 2, 4), ('建设', 4, 6), ('兵团', 6, 8)]
# ngram: n=2
# [-7.551418304443359, -7.551418304443359, -7.9017534255981445, -6.074876308441162, -7.295460224151611, -7.295460224151611]
# ngram: n=3
# [-11.65687370300293, -11.65687370300293, -11.65687370300293, -10.411882400512695, -6.108068943023682, -6.108068943023682, -6.108068943023682]
# med_abs_deviation: 1.2939362923304252
# y_score: [0.73700888 0.6745     0.         0.5610897  0.77593753]
# median: [-8.19029494]
# scores: [-9.604146   -9.48423123 -8.19029494 -7.11392085 -6.70176458]
# 新讲生产建设兵团 []
#
#
# [('坐位', 0, 2), ('新', 2, 3), ('时代', 3, 5), ('的', 5, 6), ('接班人', 6, 9), ('物理', 9, 11), ('取闹', 11, 13)]
# ngram: n=2
# [-9.164161682128906, -9.164161682128906, -7.018512725830078, -4.766091346740723, -6.6565985679626465, -10.101886749267578, -11.431344985961914, -11.431344985961914]
# ngram: n=3
# [-12.915098190307617, -12.915098190307617, -12.915098190307617, -8.43337345123291, -9.926911354064941, -11.915477752685547, -16.982120513916016, -16.982120513916016, -16.982120513916016]
# med_abs_deviation: 2.3695547978083304
# y_score: [0.1079565  0.2573571  0.71210355 0.7852826  0.         0.6745
#  1.00948064]
# median: [-10.66037293]
# scores: [-11.03962994  -9.75626357  -8.15871485  -7.90163291 -10.66037293
#  -13.02992773 -14.20673275]
# 座位新时代的接班人物理取闹 [['坐位', '座位', 0, 2]]
#
#
# cut_words:
# [('我们', 0, 2), ('不太', 2, 4), ('敢说话', 4, 7), ('了', 7, 8), ('已经', 8, 10)]
# ngram: n=2
# [-10.073805809020996, -10.073805809020996, -12.974815368652344, -9.121642112731934, -5.977187156677246, -5.977187156677246]
# ngram: n=3
# [-16.879825592041016, -16.879825592041016, -16.879825592041016, -15.497016906738281, -12.576627731323242, -12.576627731323242, -12.576627731323242]
# med_abs_deviation: 0.9552405675252285
# y_score: [0.32513042 0.6745     0.         1.74168296 2.64044518]
# median: [-13.01635941]
# scores: [-13.4768157  -13.97159998 -13.01635941 -10.54975271  -9.27690744]
# 我们不太敢说话了已经 []
#
#
# [('此', 0, 1), ('函数', 1, 3), ('其实', 3, 5), ('就是', 5, 7), ('将', 7, 8), ('环境变量', 8, 12), ('座位', 12, 14), ('在', 14, 15), ('p', 15, 16), ('at', 16, 18), ('h', 18, 19), ('参数', 19, 21), ('里面', 21, 23), ('做', 23, 24), ('替换', 24, 26), (',', 26, 27), ('如果', 27, 29), ('环境变量', 29, 33), ('不', 33, 34), ('存在', 34, 36), (',', 36, 37), ('就', 37, 38), ('原样', 38, 40), ('返回', 40, 42), ('。', 42, 43)]
# ngram: n=2
# [-10.135616302490234, -10.135616302490234, -9.938329696655273, -5.361819267272949, -5.840907573699951, -9.97283935546875, -11.00001335144043, -6.995171546936035, -8.902959823608398, -12.651937484741211, -12.304532051086426, -10.749246597290039, -8.909974098205566, -6.503015518188477, -7.575140953063965, -8.029123306274414, -5.349051475524902, -10.771804809570312, -9.375178337097168, -5.115281105041504, -6.570872783660889, -5.113883972167969, -8.801565170288086, -9.633380889892578, -5.4418253898620605, -5.4418253898620605]
# ngram: n=3
# [-14.15152359008789, -14.15152359008789, -14.15152359008789, -11.41523265838623, -8.352551460266113, -13.362502098083496, -14.373412132263184, -13.594612121582031, -13.67222785949707, -15.717577934265137, -18.35702896118164, -17.34868621826172, -14.776519775390625, -11.681863784790039, -11.053136825561523, -10.821532249450684, -10.529668807983398, -12.460833549499512, -13.547542572021484, -11.7147216796875, -8.571220397949219, -9.0109281539917, -11.435738563537598, -13.041593551635742, -11.06408977508545, -11.06408977508545, -11.06408977508545]
# med_abs_deviation: 1.2187612851460798
# y_score: [1.12811466 0.84842727 0.34695255 0.98664055 0.07581252 1.12150907
#  0.73809445 0.57193475 1.79386984 2.60361439 2.25356071 1.16819053
#  0.         0.5494864  0.44461434 0.62276717 0.00814692 0.6745
#  0.46689551 1.27334309 1.29926937 0.57829557 0.23639207 0.26273409
#  1.02506995]
# median: [-10.10516747]
# scores: [-12.14356995 -11.63819981  -9.47825519  -8.32239608  -9.96818101
#  -12.13163424 -11.43883824 -11.1386025  -13.34653012 -14.80966624
#  -14.17715049 -12.21598347 -10.10516747  -9.11229459  -9.30178905
#   -8.9798828  -10.11988823 -11.32392875  -9.26152897  -7.80435018
#   -7.75750371  -9.060239   -10.53230683  -9.63043042  -8.25295758]
# 此函数其实就是将环境变量座位在path参数里面做替换，如果环境变量不存在，就原样返回。 []

# %%
sent = '这些方法是非常食用的'
sent, detail = pycorrector.correct(sent)
print(sent,detail)
# Out:
# [('这些', 0, 2), ('方法', 2, 4), ('是非', 4, 6), ('常', 6, 7), ('食用', 7, 9), ('的', 9, 10)]
# ngram: n=2
# [-6.867339134216309, -6.867339134216309, -9.24550724029541, -8.960851669311523, -6.478952407836914, -5.325277328491211, -5.325277328491211]
# ngram: n=3
# [-12.515535354614258, -12.515535354614258, -12.515535354614258, -13.429703712463379, -11.477705001831055, -7.91664981842041, -7.91664981842041, -7.91664981842041]
# med_abs_deviation: 1.1025115251541138
# y_score: [0.11036901 0.56731331 0.78168669 0.11036901 1.2285504  1.76810069]
# median: [-9.51103234]
# scores: [ -9.69143724 -10.43834066 -10.78874707  -9.33062744  -7.50289154
#   -6.62096357]
# 这些方法是非常食用的 []

# %%
sent = '这些方法是非常实用的'
sent, detail = pycorrector.correct(sent)
print(sent,detail)
# Out:
# [('这些', 0, 2), ('方法', 2, 4), ('是非', 4, 6), ('常', 6, 7), ('实用', 7, 9), ('的', 9, 10)]
# ngram: n=2
# [-6.867339134216309, -6.867339134216309, -9.24550724029541, -8.960851669311523, -8.919893264770508, -5.2522478103637695, -5.2522478103637695]
# ngram: n=3
# [-12.515535354614258, -12.515535354614258, -12.515535354614258, -13.429703712463379, -13.918645858764648, -9.62895393371582, -9.62895393371582, -9.62895393371582]
# med_abs_deviation: 0.780304630597433
# y_score: [0.3228139  0.3228139  0.97736795 0.49113923 0.85786077 2.26845035]
# median: [-10.06488895]
# scores: [ -9.69143724 -10.43834066 -11.19557055 -10.63307015  -9.07246089
#   -7.44060087]
# 这些方法是非常实用的 []

# %%
sent = '关于外交事物，我们必须十分谨慎才可以的'
sent, detail = pycorrector.correct(sent)
print(sent,detail)
# Out:
# [('关于', 0, 2), ('外交', 2, 4), ('事物', 4, 6), (',', 6, 7), ('我们', 7, 9), ('必须', 9, 11), ('十', 11, 12), ('分', 12, 13), ('谨慎', 13, 15), ('才', 15, 16), ('可以', 16, 18), ('的', 18, 19)]
# ngram: n=2
# [-7.701910972595215, -7.701910972595215, -9.457276344299316, -7.2831268310546875, -5.359715938568115, -6.163232326507568, -7.981159210205078, -8.126656532287598, -8.611581802368164, -8.21739387512207, -5.210103988647461, -5.497365951538086, -5.497365951538086]
# ngram: n=3
# [-13.154439926147461, -13.154439926147461, -13.154439926147461, -11.874530792236328, -9.969014167785645, -7.43984317779541, -10.874946594238281, -12.187893867492676, -13.07942008972168, -12.34787368774414, -10.168984413146973, -7.879795551300049, -7.879795551300049, -7.879795551300049]
# med_abs_deviation: 1.1219781041145325
# y_score: [0.66681041 0.80238825 0.42028416 0.76812321 1.03658846 0.42028416
#  0.43986172 0.68218959 0.49354198 0.53865165 1.39513107 1.58132315]
# median: [-9.31898838]
# scores: [-10.42817545 -10.6536986  -10.01809827  -8.04127538  -7.59470439
#   -8.61987849 -10.05066403 -10.45375752 -10.13995695  -8.42298341
#   -6.99829674  -6.68858075]
# 关于外交事物，我们必须十分谨慎才可以的 []

# %%
sent = '关于外交事务，我们必须十分谨慎才可以的'
sent, detail = pycorrector.correct(sent)
print(sent,detail)
# Out:
# [('关于', 0, 2), ('外交事务', 2, 6), (',', 6, 7), ('我们', 7, 9), ('必须', 9, 11), ('十', 11, 12), ('分', 12, 13), ('谨慎', 13, 15), ('才', 15, 16), ('可以', 16, 18), ('的', 18, 19)]
# ngram: n=2
# [-10.726645469665527, -10.726645469665527, -9.44794750213623, -5.359715938568115, -6.163232326507568, -7.981159210205078, -8.126656532287598, -8.611581802368164, -8.21739387512207, -5.210103988647461, -5.497365951538086, -5.497365951538086]
# ngram: n=3
# [-13.575152397155762, -13.575152397155762, -13.575152397155762, -11.95915699005127, -7.43984317779541, -10.874946594238281, -12.187893867492676, -13.07942008972168, -12.34787368774414, -10.168984413146973, -7.879795551300049, -7.879795551300049, -7.879795551300049]
# med_abs_deviation: 1.2561495701471976
# y_score: [1.58579425 1.26952199 0.         0.68258849 0.31021666 0.45805558
#  0.6745     0.50600216 0.41594112 1.18093852 1.34724311]
# median: [-9.19760795]
# scores: [-12.15089893 -11.56189187  -9.19760795  -7.92639486  -8.61987849
#  -10.05066403 -10.45375752 -10.13995695  -8.42298341  -6.99829674
#   -6.68858075]
# 关于外交事务，我们必须十分谨慎才可以的 []

# %% [markdown]
# ### 纠错调试（与结果无关）

# %%
import jieba
words = '权力和义务是对等的'
word = jieba.cut(words)
print(' '.join(word))
# Out:
# 权力 和义 务是 对 等 的

# %%
# !pip install pyltp
# Out:
# Requirement already satisfied: pyltp in /usr/local/lib/python3.6/dist-packages (0.2.1)

# %%
import os
from pyltp import Segmentor
LTP_DATA_DIR='/content/drive/My Drive/Colab Notebooks/PyTorch/data/ltp_data_v3.4.0'
cws_model_path=os.path.join(LTP_DATA_DIR,'cws.model')
segmentor=Segmentor()
segmentor.load(cws_model_path)
words=segmentor.segment('权力和义务是对等的')
print(type(words))
print(' '.join(words))
words_list = ' '.join(words).split(' ')
# segmentor.release()
token = list(yield_tuple(words_list))

def yield_tuple(words_list):
  start = 0
  for w in words_list:
    width = len(w)
    yield(w, start, start + width)
    start += width
# Out:
# <class 'pyltp.VectorOfString'>
# 权力 和 义务 是 对等 的
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8a2616b6c0dd> in <module>()
#      10 words_list = ' '.join(words).split(' ')
#      11 # segmentor.release()
# ---> 12 token = list(yield_tuple(words_list))
#      13
#      14 def yield_tuple(words_list):
#
# NameError: name 'yield_tuple' is not defined

# %%
words=segmentor.segment('<s>这些方法是非常实用的</s>')
print(type(words))
print(' '.join(words))
# segmentor.release()

# %%
words=segmentor.segment('这些方法是非常实用的')
print(type(words))
print(' '.join(words))
# segmentor.release()

# %%
for i in range(0):
  print("hello")
